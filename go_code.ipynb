# %% [markdown]
# # Go Programming Workspace
#
# Write and execute your Go code in the cells below.

# %%
import "fmt"

fmt.Println("Hello, Go!")

# %% [markdown]
# ---
#
# ## Your Code Here
#
# Add new cells below to write and execute your Go code.

# %%
// Write your Go code here
